# %%
# titanic dataset

# %%
#loading dataset and importing libraries

# %%
import pandas as pd
import numpy as np
from sklearn.preprocessing import StandardScaler
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv(r'C:/Users/Asus/Downloads/archive (1)/tested.csv')

# %%
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0            892         0       3
# 1            893         1       3
# 2            894         0       2
# 3            895         0       3
# 4            896         1       3
# ..           ...       ...     ...
# 413         1305         0       3
# 414         1306         1       1
# 415         1307         0       3
# 416         1308         0       3
# 417         1309         0       3
#
#                                              Name     Sex   Age  SibSp  Parch  \
# 0                                Kelly, Mr. James    male  34.5      0      0
# 1                Wilkes, Mrs. James (Ellen Needs)  female  47.0      1      0
# 2                       Myles, Mr. Thomas Francis    male  62.0      0      0
# 3                                Wirz, Mr. Albert    male  27.0      0      0
# 4    Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female  22.0      1      1
# ...

# %%
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0          892         0       3
# 1          893         1       3
# 2          894         0       2
# 3          895         0       3
# 4          896         1       3
#
#                                            Name     Sex   Age  SibSp  Parch  \
# 0                              Kelly, Mr. James    male  34.5      0      0
# 1              Wilkes, Mrs. James (Ellen Needs)  female  47.0      1      0
# 2                     Myles, Mr. Thomas Francis    male  62.0      0      0
# 3                              Wirz, Mr. Albert    male  27.0      0      0
# 4  Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female  22.0      1      1
#
#     Ticket     Fare Cabin Embarked
# 0   330911   7.8292   NaN        Q
# 1   363272   7.0000   NaN        S
# 2   240276   9.6875   NaN        Q
# 3   315154   8.6625   NaN        S
# 4  3101298  12.2875   NaN        S

# %%
df.tail()
# Out:
#      PassengerId  Survived  Pclass                          Name     Sex  \
# 413         1305         0       3            Spector, Mr. Woolf    male
# 414         1306         1       1  Oliva y Ocana, Dona. Fermina  female
# 415         1307         0       3  Saether, Mr. Simon Sivertsen    male
# 416         1308         0       3           Ware, Mr. Frederick    male
# 417         1309         0       3      Peter, Master. Michael J    male
#
#       Age  SibSp  Parch              Ticket      Fare Cabin Embarked
# 413   NaN      0      0           A.5. 3236    8.0500   NaN        S
# 414  39.0      0      0            PC 17758  108.9000  C105        C
# 415  38.5      0      0  SOTON/O.Q. 3101262    7.2500   NaN        S
# 416   NaN      0      0              359309    8.0500   NaN        S
# 417   NaN      1      1                2668   22.3583   NaN        C

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 418 entries, 0 to 417
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  418 non-null    int64
#  1   Survived     418 non-null    int64
#  2   Pclass       418 non-null    int64
#  3   Name         418 non-null    object
#  4   Sex          418 non-null    object
#  5   Age          332 non-null    float64
#  6   SibSp        418 non-null    int64
#  7   Parch        418 non-null    int64
#  8   Ticket       418 non-null    object
#  9   Fare         417 non-null    float64
#  10  Cabin        91 non-null     object
#  11  Embarked     418 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 39.3+ KB

# %%
print(df.isnull().sum())
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age             86
# SibSp            0
# Parch            0
# Ticket           0
# Fare             1
# Cabin          327
# Embarked         0
# dtype: int64

# %%
# --- 2. Handle missing values using mean/median/imputation and drop columns ---

# %%
# Fill missing 'Fare' with the mean
df['Fare'].fillna(df['Fare'].mean(), inplace=True)

# %%
# Fill missing 'Age' with the median
df['Age'].fillna(df['Age'].median(), inplace=True)

# %%
import warnings

# %%
# Temporarily filter out all warnings
warnings.filterwarnings('ignore')

# %%
# Fill missing 'Fare' with the mean
df['Fare'].fillna(df['Fare'].mean(), inplace=True)

# %%
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0            892         0       3
# 1            893         1       3
# 2            894         0       2
# 3            895         0       3
# 4            896         1       3
# ..           ...       ...     ...
# 413         1305         0       3
# 414         1306         1       1
# 415         1307         0       3
# 416         1308         0       3
# 417         1309         0       3
#
#                                              Name     Sex   Age  SibSp  Parch  \
# 0                                Kelly, Mr. James    male  34.5      0      0
# 1                Wilkes, Mrs. James (Ellen Needs)  female  47.0      1      0
# 2                       Myles, Mr. Thomas Francis    male  62.0      0      0
# 3                                Wirz, Mr. Albert    male  27.0      0      0
# 4    Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female  22.0      1      1
# ...

# %%
# Fill missing 'Age' with the median
df['Age'].fillna(df['Age'].median(), inplace=True)

# %%
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0            892         0       3
# 1            893         1       3
# 2            894         0       2
# 3            895         0       3
# 4            896         1       3
# ..           ...       ...     ...
# 413         1305         0       3
# 414         1306         1       1
# 415         1307         0       3
# 416         1308         0       3
# 417         1309         0       3
#
#                                              Name     Sex   Age  SibSp  Parch  \
# 0                                Kelly, Mr. James    male  34.5      0      0
# 1                Wilkes, Mrs. James (Ellen Needs)  female  47.0      1      0
# 2                       Myles, Mr. Thomas Francis    male  62.0      0      0
# 3                                Wirz, Mr. Albert    male  27.0      0      0
# 4    Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female  22.0      1      1
# ...

# %%
# Drop columns: Cabin (too many nulls), Name, Ticket (high-cardinality), PassengerId (identifier)
df.drop(['Cabin', 'Name', 'Ticket', 'PassengerId'], axis=1, inplace=True)

# %%
df
# Out:
#      Survived  Pclass     Sex   Age  SibSp  Parch      Fare Embarked
# 0           0       3    male  34.5      0      0    7.8292        Q
# 1           1       3  female  47.0      1      0    7.0000        S
# 2           0       2    male  62.0      0      0    9.6875        Q
# 3           0       3    male  27.0      0      0    8.6625        S
# 4           1       3  female  22.0      1      1   12.2875        S
# ..        ...     ...     ...   ...    ...    ...       ...      ...
# 413         0       3    male  27.0      0      0    8.0500        S
# 414         1       1  female  39.0      0      0  108.9000        C
# 415         0       3    male  38.5      0      0    7.2500        S
# 416         0       3    male  27.0      0      0    8.0500        S
# 417         0       3    male  27.0      1      1   22.3583        C
#
# [418 rows x 8 columns]

# %%
# --- 3. Convert categorical features into numerical using encoding ---
# Convert 'Sex' and 'Embarked' to numerical using one-hot encoding
df_encoded = pd.get_dummies(df, columns=['Sex', 'Embarked'], drop_first=True)

# %%
df
# Out:
#      Survived  Pclass     Sex   Age  SibSp  Parch      Fare Embarked
# 0           0       3    male  34.5      0      0    7.8292        Q
# 1           1       3  female  47.0      1      0    7.0000        S
# 2           0       2    male  62.0      0      0    9.6875        Q
# 3           0       3    male  27.0      0      0    8.6625        S
# 4           1       3  female  22.0      1      1   12.2875        S
# ..        ...     ...     ...   ...    ...    ...       ...      ...
# 413         0       3    male  27.0      0      0    8.0500        S
# 414         1       1  female  39.0      0      0  108.9000        C
# 415         0       3    male  38.5      0      0    7.2500        S
# 416         0       3    male  27.0      0      0    8.0500        S
# 417         0       3    male  27.0      1      1   22.3583        C
#
# [418 rows x 8 columns]

# %%
# --- 4. Normalize/standardize the numerical features ---
numerical_features = ['Pclass', 'Age', 'SibSp', 'Parch', 'Fare']
scaler = StandardScaler()
df_scaled = df_encoded.copy()
df_scaled[numerical_features] = scaler.fit_transform(df_scaled[numerical_features])

# %%
df
# Out:
#      Survived  Pclass     Sex   Age  SibSp  Parch      Fare Embarked
# 0           0       3    male  34.5      0      0    7.8292        Q
# 1           1       3  female  47.0      1      0    7.0000        S
# 2           0       2    male  62.0      0      0    9.6875        Q
# 3           0       3    male  27.0      0      0    8.6625        S
# 4           1       3  female  22.0      1      1   12.2875        S
# ..        ...     ...     ...   ...    ...    ...       ...      ...
# 413         0       3    male  27.0      0      0    8.0500        S
# 414         1       1  female  39.0      0      0  108.9000        C
# 415         0       3    male  38.5      0      0    7.2500        S
# 416         0       3    male  27.0      0      0    8.0500        S
# 417         0       3    male  27.0      1      1   22.3583        C
#
# [418 rows x 8 columns]

# %%
# --- 5. Visualize and remove outliers ---

# %%
# Assuming df_encoded is the DataFrame after handling nulls and encoding categorical variables

# Columns we want to visualize for outliers
numerical_features = ['Age', 'Fare', 'SibSp', 'Parch']

# %%
# Create the plot
plt.figure(figsize=(15, 5))

# %%
for i, col in enumerate(numerical_features):
    plt.subplot(1, 4, i + 1)
    # Use boxplot for visualization
    sns.boxplot(y=df_encoded[col])
    plt.title(f'Outliers in {col}', fontsize=12)
    plt.ylabel(col, fontsize=10)
    
plt.suptitle('Outlier Visualization using Boxplots (on Unscaled Data)', fontsize=14, y=1.02)
plt.tight_layout()
plt.savefig('outlier_boxplots_visualization.png')
plt.open()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[77], line 11
#       9 plt.tight_layout()
#      10 plt.savefig('outlier_boxplots_visualization.png')
# ---> 11 plt.open()
#
# AttributeError: module 'matplotlib.pyplot' has no attribute 'open'

# %%
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
# --- 1. Calculate IQR bounds using the UN-SCALED data (df_encoded) ---

# Calculate bounds for Age
Q1_age = df_encoded['Age'].quantile(0.25)
Q3_age = df_encoded['Age'].quantile(0.75)
IQR_age = Q3_age - Q1_age
lower_bound_age = Q1_age - 1.5 * IQR_age
upper_bound_age = Q3_age + 1.5 * IQR_age

# Calculate bounds for Fare
Q1_fare = df_encoded['Fare'].quantile(0.25)
Q3_fare = df_encoded['Fare'].quantile(0.75)
IQR_fare = Q3_fare - Q1_fare
lower_bound_fare = Q1_fare - 1.5 * IQR_fare
upper_bound_fare = Q3_fare + 1.5 * IQR_fare

# --- 2. Create boolean mask (conditions) based on the UN-SCALED data ---

# Condition for rows within the Age IQR bounds
age_condition = (df_encoded['Age'] >= lower_bound_age) & (df_encoded['Age'] <= upper_bound_age)

# Condition for rows within the Fare IQR bounds
fare_condition = (df_encoded['Fare'] >= lower_bound_fare) & (df_encoded['Fare'] <= upper_bound_fare)

# Combine the conditions (a row must satisfy BOTH to be kept)
final_condition = age_condition & fare_condition

# --- 3. Apply the final condition/mask to the SCALED data (df_scaled) ---

# This filters the scaled data, keeping only the rows that met the unscaled IQR criteria
df_no_outliers = df_scaled[final_condition].reset_index(drop=True)

print(f"Original scaled rows: {len(df_scaled)}")
print(f"Rows after outlier removal (Age and Fare): {len(df_no_outliers)}")
print("\nHead of the final outlier-free, scaled DataFrame:")
print(df_no_outliers.head())
# Out:
# Original scaled rows: 418
# Rows after outlier removal (Age and Fare): 340
#
# Head of the final outlier-free, scaled DataFrame:
#    Survived    Pclass       Age     SibSp     Parch      Fare  Sex_male  \
# 0         0  0.873482  0.386231 -0.499470 -0.400248 -0.498407      True
# 1         1  0.873482  1.371370  0.616992 -0.400248 -0.513274     False
# 2         0  0.873482 -0.204852 -0.499470 -0.400248 -0.483466      True
# 3         1  0.873482 -0.598908  0.616992  0.619896 -0.418471     False
# 4         0  0.873482 -1.229397 -0.499470 -0.400248 -0.473381      True
#
#    Embarked_Q  Embarked_S
# 0        True       False
# 1       False        True
# 2       False        True
# 3       False        True
# 4       False        True

# %%
# --- Assuming df_encoded (unscaled, encoded) and df_scaled (scaled, encoded) are available ---

# 1. Calculate IQR bounds using the UN-SCALED data (df_encoded)
Q1_age = df_encoded['Age'].quantile(0.25)
Q3_age = df_encoded['Age'].quantile(0.75)
IQR_age = Q3_age - Q1_age
lower_bound_age = Q1_age - 1.5 * IQR_age
upper_bound_age = Q3_age + 1.5 * IQR_age

Q1_fare = df_encoded['Fare'].quantile(0.25)
Q3_fare = df_encoded['Fare'].quantile(0.75)
IQR_fare = Q3_fare - Q1_fare
lower_bound_fare = Q1_fare - 1.5 * IQR_fare
upper_bound_fare = Q3_fare + 1.5 * IQR_fare

# 2. Create a boolean mask (conditions) based on the UN-SCALED data
age_condition = (df_encoded['Age'] >= lower_bound_age) & (df_encoded['Age'] <= upper_bound_age)
fare_condition = (df_encoded['Fare'] >= lower_bound_fare) & (df_encoded['Fare'] <= upper_bound_fare)

# Combine the conditions
final_condition = age_condition & fare_condition

# 3. Apply the final condition/mask to the SCALED data (df_scaled)
df_no_outliers = df_scaled[final_condition].reset_index(drop=True)

# Print results to show the effect
print(f"Original scaled rows: {len(df_scaled)}")
print(f"Rows after outlier removal: {len(df_no_outliers)}")
print("\nHead of the final outlier-free, scaled DataFrame:")
print(df_no_outliers.head())
# Out:
# Original scaled rows: 418
# Rows after outlier removal: 340
#
# Head of the final outlier-free, scaled DataFrame:
#    Survived    Pclass       Age     SibSp     Parch      Fare  Sex_male  \
# 0         0  0.873482  0.386231 -0.499470 -0.400248 -0.498407      True
# 1         1  0.873482  1.371370  0.616992 -0.400248 -0.513274     False
# 2         0  0.873482 -0.204852 -0.499470 -0.400248 -0.483466      True
# 3         1  0.873482 -0.598908  0.616992  0.619896 -0.418471     False
# 4         0  0.873482 -1.229397 -0.499470 -0.400248 -0.473381      True
#
#    Embarked_Q  Embarked_S
# 0        True       False
# 1       False        True
# 2       False        True
# 3       False        True
# 4       False        True

# %%
# Calculate IQR bounds for Age (using df_encoded)
Q1_age = df_encoded['Age'].quantile(0.25)
Q3_age = df_encoded['Age'].quantile(0.75)
IQR_age = Q3_age - Q1_age
lower_bound_age = Q1_age - 1.5 * IQR_age
upper_bound_age = Q3_age + 1.5 * IQR_age

# Calculate IQR bounds for Fare (using df_encoded)
Q1_fare = df_encoded['Fare'].quantile(0.25)
Q3_fare = df_encoded['Fare'].quantile(0.75)
IQR_fare = Q3_fare - Q1_fare
lower_bound_fare = Q1_fare - 1.5 * IQR_fare
upper_bound_fare = Q3_fare + 1.5 * IQR_fare

# %%
# Apply filters to the scaled DataFrame (df_scaled)
df_no_outliers = df_scaled.copy()

# %%
# Filter for Age outliers
df_no_outliers = df_no_outliers.loc[
    (df_encoded['Age'] >= lower_bound_age) &
    (df_encoded['Age'] <= upper_bound_age)
]

# %%
# Filter for Fare outliers
df_no_outliers = df_no_outliers.loc[
    (df_encoded['Fare'] >= lower_bound_fare) &
    (df_encoded['Fare'] <= upper_bound_fare)
]

# %%
# Reset index for the final clean DataFrame
df_final = df_no_outliers.reset_index(drop=True)

# %%
# Save the final prepared data to a CSV
df_final.to_csv("tested_cleaned_prepared_final.csv", index=False)

# %%
print("Data Cleaning and Preparation Complete. Final DataFrame head:")
print(df_final.head())
# Out:
# Data Cleaning and Preparation Complete. Final DataFrame head:
#    Survived    Pclass       Age     SibSp     Parch      Fare  Sex_male  \
# 0         0  0.873482  0.386231 -0.499470 -0.400248 -0.498407      True
# 1         1  0.873482  1.371370  0.616992 -0.400248 -0.513274     False
# 2         0  0.873482 -0.204852 -0.499470 -0.400248 -0.483466      True
# 3         1  0.873482 -0.598908  0.616992  0.619896 -0.418471     False
# 4         0  0.873482 -1.229397 -0.499470 -0.400248 -0.473381      True
#
#    Embarked_Q  Embarked_S
# 0        True       False
# 1       False        True
# 2       False        True
# 3       False        True
# 4       False        True
